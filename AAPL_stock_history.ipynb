# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.20-py2.py3-none-any.whl (62 kB)
#      -------------------------------------- 62.5/62.5 kB 828.8 kB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26 in c:\users\naveen\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.8-cp310-cp310-win_amd64.whl (35 kB)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      -------------------------------------- 112.2/112.2 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\naveen\anaconda3\lib\site-packages (from yfinance) (39.0.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\naveen\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\naveen\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\naveen\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\naveen\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\naveen\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\naveen\anaconda3\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\naveen\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in c:\users\naveen\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in c:\users\naveen\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\naveen\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\naveen\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\naveen\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\naveen\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\naveen\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\naveen\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: pycparser in c:\users\naveen\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: multitasking, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.3.8 html5lib-1.1 multitasking-0.0.11 yfinance-0.2.20

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
stock_symbol="AAPL"
start_date = "2022-06-07"
end_date = "2023-06-07"
df= yf.download(stock_symbol,start=start_date,end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.plot(df.index, df['Close'])
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Stock Performance')
plt.xticks(rotation=45)
plt.show()
